# %%
import pandas as pd
import os

# %%
movies = pd.read_csv('Movie-Ratings.csv')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',
                  'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Histograms

# %%
#already know this method:
m1 = sns.distplot(movies.AudienceRating, bins=15)

# %%
m2 = sns.distplot(movies.CriticRating, bins=15)

# %%
n1 = plt.hist(movies.AudienceRating, bins=15)

# %%
n1 = plt.hist(movies.CriticRating, bins=15)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.CriticRating, bins=15)

# %%
sns.set_style('white')

# %%
m2 = sns.distplot(movies.CriticRating, bins=15)

# %% [markdown]
# ---

# %%
# Stacked Histograms

# %%
h1 = plt.hist(movies.BudgetMillions)

# %%
movies[movies.Genre == 'Drama']
# Out:
#                     Film  Genre  CriticRating  AudienceRating  BudgetMillions  \
# 10            88 Minutes  Drama             5              51              30
# 11    A Dangerous Method  Drama            79              89              20
# 13        A Serious Man   Drama            89              64               7
# 18          Albert Nobbs  Drama            53              43               8
# 23       All Good Things  Drama            33              64              20
# ..                   ...    ...           ...             ...             ...
# 529            War Horse  Drama            77              73              66
# 532  Water For Elephants  Drama            60              72              38
# 534     We Own the Night  Drama            55              63              21
# 541             Whip It   Drama            84              73              15
# 545        Winter's Bone  Drama            94              73               2
#
#      Year
# 10   2007
# ...

# %%
mov_dr = movies[movies.Genre == 'Drama'].BudgetMillions

# %%
mov_dr
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
plt.hist(mov_dr)
plt.show()

# %%
mov_ac = movies[movies.Genre == 'Action'].BudgetMillions

# %%
mov_ac
# Out:
# 2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillions, Length: 154, dtype: int64

# %%
plt.hist(mov_ac)
plt.show()

# %%
mov_th = movies[movies.Genre == 'Thriller'].BudgetMillions

# %%
mov_th
# Out:
# 25     100
# 72      60
# 95      20
# 105     15
# 179    150
# 180     60
# 189     40
# 225     27
# 237      4
# 243     25
# 253     20
# 261     20
# 263    130
# 267     70
# 282     85
# 358     32
# 385     51
# 389     20
# 394    110
# 406    185
# 407    100
# 408     20
# 419     90
# 424     48
# 432     13
# 471     15
# 481    100
# 491     35
# 494     21
# 498     22
# 503     35
# 513     30
# 515     35
# 519     75
# 522     40
# 556     65
# Name: BudgetMillions, dtype: int64

# %%
plt.hist(mov_th)
plt.show()

# %%
plt.hist(mov_ac)
plt.hist(mov_dr)
plt.hist(mov_th)
plt.show()

# %%
plt.hist(mov_ac, bins=15)
plt.hist(mov_dr, bins=15)
plt.hist(mov_th, bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions, movies[movies.Genre == 'Drama'].BudgetMillions], bins=15, stacked=True)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,
          movies[movies.Genre == 'Drama'].BudgetMillions, 
          movies[movies.Genre == 'Thriller'].BudgetMillions], 
          bins=15, stacked=True)
plt.show()

# %%
movies.Genre = movies.Genre.astype('category')

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)

# %%
list1
# Out:
# [2       20
#  5      200
#  15      35
#  29      20
#  30      20
#        ...
#  531    130
#  542     35
#  546    150
#  547    160
#  557     24
#  Name: BudgetMillions, Length: 154, dtype: int64,
#  1      105
#  3       18
#  19     200
#  21      45
#  24      40
#  32      78
#  46      20
#  65      38
#  68     140
#  130     73
#  165     12
#  166    125
#  167    250
#  168    150
#  176     36
#  178    150
#  192     70
#  193     60
#  241     60
#  272     37
#  341     19
#  363     70
#  386    130
#  401    155
#  459     59
#  463     25
#  506     38
#  540    100
#  548     60
#  Name: BudgetMillions, dtype: int64,
#  0       8
#  4      20
#  6      30
#  8      28
#  9       8
#         ..
#  552    80
#  553    22
#  554    50
#  555    18
#  558    80
#  Name: BudgetMillions, Length: 172, dtype: int64,
#  10     30
#  11     20
#  13      7
#  18      8
#  23     20
#         ..
#  529    66
#  532    38
#  534    21
#  541    15
#  545     2
# ...

# %%
h = plt.hist(list1)

# %%
h = plt.hist(list1, bins=30, stacked=True, rwidth=1)

# %%
# Add labels

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    mylabels.append(gen)
    
h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.legend()
plt.show()
